# %%
import tensorflow as tf
import matplotlib.pyplot as  plt
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.optimizers import Adam

# %%
mnist=tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train,x_test=x_train/255.0,x_test/255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
model=tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10,activation='softmax')])

# %%
model.compile(optimizer='SGD',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
tf_callbacks=tf.keras.callbacks.TensorBoard(log_dir="logs/fit",histogram_freq=1)

# %%
history=model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=10,callbacks=tf_callbacks)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 33s 16ms/step - loss: 0.6310 - accuracy: 0.8381 - val_loss: 0.3409 - val_accuracy: 0.9083
# Epoch 2/10
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.3417 - accuracy: 0.9026 - val_loss: 0.2759 - val_accuracy: 0.9231
# Epoch 3/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2897 - accuracy: 0.9178 - val_loss: 0.2398 - val_accuracy: 0.9329
# Epoch 4/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2553 - accuracy: 0.9285 - val_loss: 0.2174 - val_accuracy: 0.9384
# Epoch 5/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2300 - accuracy: 0.9358 - val_loss: 0.1971 - val_accuracy: 0.9444
# Epoch 6/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2089 - accuracy: 0.9413 - val_loss: 0.1840 - val_accuracy: 0.9470
# Epoch 7/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.1926 - accuracy: 0.9464 - val_loss: 0.1697 - val_accuracy: 0.9526
# Epoch 8/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.1797 - accuracy: 0.9493 - val_loss: 0.1591 - val_accuracy: 0.9549
# Epoch 9/10
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.1674 - accuracy: 0.9526 - val_loss: 0.1497 - val_accuracy: 0.9573
# Epoch 10/10
# 1875/1875 [==============================] - 29s 15ms/step - loss: 0.1587 - accuracy: 0.9557 - val_loss: 0.1434 - val_accuracy: 0.9587

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
tensorboard--logdir logs/fit
# Out:
#       <iframe id="tensorboard-frame-8861a31ff9c61b15" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8861a31ff9c61b15");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import matplotlib.pyplot as  plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as  plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'],loc='upper left')
plt.show()
