# %%
import pandas as pd
df=pd.read_csv('D:\\AI ML B2\\creditcar1.csv')
df
# Out:
#    Credit_Limit  Avg_Purchase
# 0         12691         11914
# 1          8256          7392
# 2          3418          3418
# 3          3313           796
# 4          4716          4716
# 5          4010          2763
# 6         34516         32252
# 7         29081         27685
# 8         22352         19835

# %%
x=df['Credit_Limit'].plot(kind="hist")
x=df['Avg_Purchase'].plot(kind="hist")

# %%
x=df.plot("Credit_Limit","Avg_Purchase",kind="scatter",color="red",marker="*",figsize=(10,7))
x.set_xlabel("Credit_Limit")
x.set_ylabel("Avg_Purchase")
x.set_title("Credit_Limit vs Avg_Purchase",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Credit_Limit vs Avg_Purchase')

# %%
df["Credit_Limit"].describe()
# Out:
# count        9.000000
# mean     13594.777778
# std      12059.805873
# min       3313.000000
# 25%       4010.000000
# 50%       8256.000000
# 75%      22352.000000
# max      34516.000000
# Name: Credit_Limit, dtype: float64

# %%
x=df["Credit_Limit"].plot(kind="box")
x.set_title("credit Limit title")
# Out:
# Text(0.5, 1.0, 'credit Limit title')
