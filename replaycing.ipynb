# %%
import pandas as pd
cars_df =pd.read_csv('D:\\AI ML B2\\Cars93.csv')
cars_df
# Out:
#     Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0            1        Acura  Integra    Small       12.9   15.9       18.8
# 1            2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2            3         Audi       90  Compact       25.9   29.1       32.3
# 3            4         Audi      100  Midsize       30.8   37.7       44.6
# 4            5          BMW     535i  Midsize       23.7   30.0       36.2
# ..         ...          ...      ...      ...        ...    ...        ...
# 88          89   Volkswagen  Eurovan      Van       16.6   19.7       22.7
# 89          90   Volkswagen   Passat  Compact       17.6   20.0       22.4
# 90          91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7
# 91          92        Volvo      240  Compact       21.8   22.7       23.5
# 92          93        Volvo      850  Midsize       24.8   26.7       28.5
#
# ...

# %%
df=cars_df.drop(['Model'],axis=1)
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Manufacturer           0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags                0
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         2
# Luggage.room          11
# Weight                 0
# Origin                 0
# Make                   0
# dtype: int64

# %%
df=cars_df.dropna(axis=0)
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Manufacturer          0
# Model                 0
# Type                  0
# Min.Price             0
# Price                 0
# Max.Price             0
# MPG.city              0
# MPG.highway           0
# AirBags               0
# DriveTrain            0
# Cylinders             0
# EngineSize            0
# Horsepower            0
# RPM                   0
# Rev.per.mile          0
# Man.trans.avail       0
# Fuel.tank.capacity    0
# Passengers            0
# Length                0
# Wheelbase             0
# Width                 0
# Turn.circle           0
# Rear.seat.room        0
# Luggage.room          0
# Weight                0
# Origin                0
# Make                  0
# dtype: int64

# %% [markdown]
#                     Replyacing with Arbitary value

# %%
cars_df['Luggage.room']=cars_df['Luggage.room'].fillna(0)
cars_df['Luggage.room'].isnull().sum()
# Out:
# 0

# %% [markdown]
#                     Replyacing with Mean

# %%
cars_df['Price']=cars_df['Price'].fillna(cars_df['Price'].mean())
cars_df['Price']
# Out:
# 0     15.9
# 1     33.9
# 2     29.1
# 3     37.7
# 4     30.0
#       ...
# 88    19.7
# 89    20.0
# 90    23.3
# 91    22.7
# 92    26.7
# Name: Price, Length: 93, dtype: float64

# %% [markdown]
#                   Replyacing with Mode

# %%
cars_df['Luggage.room']=cars_df['Luggage.room'].fillna(cars_df['Luggage.room'].mode()[0])
cars_df['Luggage.room']
# Out:
# 0     11.0
# 1     15.0
# 2     14.0
# 3     17.0
# 4     13.0
#       ...
# 88     0.0
# 89    14.0
# 90    15.0
# 91    14.0
# 92    15.0
# Name: Luggage.room, Length: 93, dtype: float64

# %% [markdown]
#                   Replyacing with Median

# %%
cars_df['Max.Price']=cars_df['Max.Price'].fillna(cars_df['Max.Price'].median())
cars_df['Max.Price']
# Out:
# 0     18.8
# 1     38.7
# 2     32.3
# 3     44.6
# 4     36.2
#       ...
# 88    22.7
# 89    22.4
# 90    23.7
# 91    23.5
# 92    28.5
# Name: Max.Price, Length: 93, dtype: float64
